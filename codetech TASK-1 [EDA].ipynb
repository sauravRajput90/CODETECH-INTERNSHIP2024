# %% [markdown]
# # TASK-1
# #EXPLORATORY DATA ANALYSIS (EDA)
#
#
# In This Project, Start with a dataset of your choice and perform EDA using libraries like pandas, numpy,
# and matplotlib or seaborn. Explore the data's characteristics, distributions, correlations,
# and outliers. Visualize your findings with histograms, scatter plots, and heatmaps to
# gain insights into the data.

# %% [markdown]
#  IMPORT PYTHON LIBRARIES

# %%
# IMPORT THE LIBRARIES
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import os 

# %matplotlib inline

# %%
# READING THE DATASET
import pandas as pd
df =pd.read_excel("E:\online retail.xlsx")

# %%
# OBSERVING FIRST FIVE ROWS
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# rearrange all the columns for easy reference
df=df[['CustomerID','InvoiceNo','StockCode','Quantity','UnitPrice','Description','InvoiceDate','Country']]

# %%
# OBSERVING FIRST FIVE ROWS
df.head()
# Out:
#    CustomerID InvoiceNo StockCode  Quantity  UnitPrice  \
# 0     17850.0    536365    85123A         6       2.55
# 1     17850.0    536365     71053         6       3.39
# 2     17850.0    536365    84406B         8       2.75
# 3     17850.0    536365    84029G         6       3.39
# 4     17850.0    536365    84029E         6       3.39
#
#                            Description         InvoiceDate         Country
# 0   WHITE HANGING HEART T-LIGHT HOLDER 2010-12-01 08:26:00  United Kingdom
# 1                  WHITE METAL LANTERN 2010-12-01 08:26:00  United Kingdom
# 2       CREAM CUPID HEARTS COAT HANGER 2010-12-01 08:26:00  United Kingdom
# 3  KNITTED UNION FLAG HOT WATER BOTTLE 2010-12-01 08:26:00  United Kingdom
# 4       RED WOOLLY HOTTIE WHITE HEART. 2010-12-01 08:26:00  United Kingdom

# %%
# CHECKING FOR NON VALUES 
df.isnull().sum()
# Out:
# CustomerID     135080
# InvoiceNo           0
# StockCode           0
# Quantity            0
# UnitPrice           0
# Description      1454
# InvoiceDate         0
# Country             0
# dtype: int64

# %%
# FINDING REVENUE 
AmountTotal=df['Quantity'] * df['UnitPrice']
df.insert(loc=5,column='TotalAmount',value=TotalAmount)

# %%
# UPDATING COLUMNS 
new_df= df[['CustomerID','InvoiceNo','StockCode','Quantity','TotalAmount','InvoiceDate','Country']]

# %%
new_df.head()
# Out:
#    CustomerID InvoiceNo StockCode  Quantity  TotalAmount         InvoiceDate  \
# 0     17850.0    536365    85123A         6        15.30 2010-12-01 08:26:00
# 1     17850.0    536365     71053         6        20.34 2010-12-01 08:26:00
# 2     17850.0    536365    84406B         8        22.00 2010-12-01 08:26:00
# 3     17850.0    536365    84029G         6        20.34 2010-12-01 08:26:00
# 4     17850.0    536365    84029E         6        20.34 2010-12-01 08:26:00
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# 3  United Kingdom
# 4  United Kingdom

# %%
# the total quantity sold for each country, sorted from highest to lowest.
country_price=new_df.groupby('Country')['Quantity'].sum().sort_values(ascending=False)
country_price
# Out:
# Country
# United Kingdom          4263829
# Netherlands              200128
# EIRE                     142637
# Germany                  117448
# France                   110480
# Australia                 83653
# Sweden                    35637
# Switzerland               30325
# Spain                     26824
# Japan                     25218
# Belgium                   23152
# Norway                    19247
# Portugal                  16180
# Finland                   10666
# Channel Islands            9479
# Denmark                    8188
# Italy                      7999
# Cyprus                     6317
# Singapore                  5234
# Austria                    4827
# Hong Kong                  4769
# Israel                     4353
# Poland                     3653
# Unspecified                3300
# Canada                     2763
# Iceland                    2458
# Greece                     1556
# USA                        1034
# United Arab Emirates        982
# ...

# %%
# TOP 5 COUNTRIES BY PRICE 
country_price[:5].plot(kind='bar', title='Top 5 Countries by Price', xlabel='Country', ylabel='Price')
# Out:
# <Axes: title={'center': 'Top 5 Countries by Price'}, xlabel='Country', ylabel='Price'>

# %%
# PRICE DISTRIBUTION ( FROM RANK 33)
country_price[33:].plot(kind='bar', title='Price Distribution (From Rank 33)', xlabel='Country', ylabel='Price')
# Out:
# <Axes: title={'center': 'Price Distribution (From Rank 33)'}, xlabel='Country', ylabel='Price'>

# %%
# the original 'InvoiceDate' column and a new 'Year' column containing the extracted years.
timest=new_df['InvoiceDate'].dt.year

new_df.loc[:, 'Year'] = timest


new_df.head()
# Out:
#    CustomerID InvoiceNo StockCode  Quantity  TotalAmount         InvoiceDate  \
# 0     17850.0    536365    85123A         6        15.30 2010-12-01 08:26:00
# 1     17850.0    536365     71053         6        20.34 2010-12-01 08:26:00
# 2     17850.0    536365    84406B         8        22.00 2010-12-01 08:26:00
# 3     17850.0    536365    84029G         6        20.34 2010-12-01 08:26:00
# 4     17850.0    536365    84029E         6        20.34 2010-12-01 08:26:00
#
#           Country  Year  Mon     Month
# 0  United Kingdom  2010   12  December
# 1  United Kingdom  2010   12  December
# 2  United Kingdom  2010   12  December
# 3  United Kingdom  2010   12  December
# 4  United Kingdom  2010   12  December

# %%
# TOTAL AMOUNT BY YEAR
new_df.groupby('Year')['TotalAmount'].sum().plot(kind='bar', title='Total Amount by Year', xlabel='Year', ylabel='Total Amount')
# Out:
# <Axes: title={'center': 'Total Amount by Year'}, xlabel='Year', ylabel='Total Amount'>

# %%
# SALES MONTH WISE 
new_df['Mon'] = new_df['InvoiceDate'].dt.month
new_df['Month']= new_df['InvoiceDate'].dt.strftime('%B')
new_df.groupby(['Mon','Year',])['TotalAmount'].sum().plot(kind='bar',title='Sales Month Wise')
# Out:
# <Axes: title={'center': 'Sales Month Wise'}, xlabel='Mon,Year'>

# %%
# calculating total sales for those specific dates.
get_2011=new_df[(new_df['Year']==2011)]
get_dec2011=new_df[new_df['Month']=='December']
get_dec2011=get_dec2011['InvoiceDate'].dt.date.unique()
get_dec2011
# Out:
# array([datetime.date(2010, 12, 1), datetime.date(2010, 12, 2),
#        datetime.date(2010, 12, 3), datetime.date(2010, 12, 5),
#        datetime.date(2010, 12, 6), datetime.date(2010, 12, 7),
#        datetime.date(2010, 12, 8), datetime.date(2010, 12, 9),
#        datetime.date(2010, 12, 10), datetime.date(2010, 12, 12),
#        datetime.date(2010, 12, 13), datetime.date(2010, 12, 14),
#        datetime.date(2010, 12, 15), datetime.date(2010, 12, 16),
#        datetime.date(2010, 12, 17), datetime.date(2010, 12, 19),
#        datetime.date(2010, 12, 20), datetime.date(2010, 12, 21),
#        datetime.date(2010, 12, 22), datetime.date(2010, 12, 23),
#        datetime.date(2011, 12, 1), datetime.date(2011, 12, 2),
#        datetime.date(2011, 12, 4), datetime.date(2011, 12, 5),
#        datetime.date(2011, 12, 6), datetime.date(2011, 12, 7),
#        datetime.date(2011, 12, 8), datetime.date(2011, 12, 9)],
#       dtype=object)

# %%
new_df.head()
# Out:
#    CustomerID InvoiceNo StockCode  Quantity  TotalAmount         InvoiceDate  \
# 0     17850.0    536365    85123A         6        15.30 2010-12-01 08:26:00
# 1     17850.0    536365     71053         6        20.34 2010-12-01 08:26:00
# 2     17850.0    536365    84406B         8        22.00 2010-12-01 08:26:00
# 3     17850.0    536365    84029G         6        20.34 2010-12-01 08:26:00
# 4     17850.0    536365    84029E         6        20.34 2010-12-01 08:26:00
#
#           Country  Year  Mon     Month
# 0  United Kingdom  2010   12  December
# 1  United Kingdom  2010   12  December
# 2  United Kingdom  2010   12  December
# 3  United Kingdom  2010   12  December
# 4  United Kingdom  2010   12  December

# %%
new_df=new_df.dropna()
new_df.isnull().sum()
# Out:
# CustomerID     0
# InvoiceNo      0
# StockCode      0
# Quantity       0
# TotalAmount    0
# InvoiceDate    0
# Country        0
# Year           0
# Mon            0
# Month          0
# dtype: int64

# %%
# MOST CUSTOMERS FOR COUNTRY
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
cus_id[:5].plot(kind='bar', title='Most Customers for country')
# Out:
# <Axes: title={'center': 'Most Customers for country'}, xlabel='Country'>

# %%
new_df2=df.copy()
new_df2= new_df2.dropna()
new_df2.isnull().sum()
new_df2.head()
# Out:
#    CustomerID InvoiceNo StockCode  Quantity  UnitPrice  TotalAmount  \
# 0     17850.0    536365    85123A         6       2.55        15.30
# 1     17850.0    536365     71053         6       3.39        20.34
# 2     17850.0    536365    84406B         8       2.75        22.00
# 3     17850.0    536365    84029G         6       3.39        20.34
# 4     17850.0    536365    84029E         6       3.39        20.34
#
#                            Description         InvoiceDate         Country
# 0   WHITE HANGING HEART T-LIGHT HOLDER 2010-12-01 08:26:00  United Kingdom
# 1                  WHITE METAL LANTERN 2010-12-01 08:26:00  United Kingdom
# 2       CREAM CUPID HEARTS COAT HANGER 2010-12-01 08:26:00  United Kingdom
# 3  KNITTED UNION FLAG HOT WATER BOTTLE 2010-12-01 08:26:00  United Kingdom
# 4       RED WOOLLY HOTTIE WHITE HEART. 2010-12-01 08:26:00  United Kingdom

# %%
# The rows will be sorted based on the 'Quantity' column in descending order.
avg_sales=new_df2.groupby(['StockCode','Description'])[['Quantity','TotalAmount']].mean().sort_values(by='Quantity',ascending=False)
avg_sales
# Out:
#                                                   Quantity  TotalAmount
# StockCode Description
# 47556B    TEA TIME TEA TOWELS                  1300.000000  3022.500000
# 84568     GIRLS ALPHABET IRON ON PATCHES        520.000000    97.200000
# 84826     ASSTD DESIGN 3D PAPER STICKERS        368.702703     9.145405
# 18007     ESSENTIAL BALM 3.5g TIN IN ENVELOPE   325.333333    21.320000
# 20914     SET/5 RED SPOTTY LID GLASS BOWLS      288.000000   734.400000
# ...                                                    ...          ...
# 21412     VINTAGE GOLD TINSEL REEL               -6.000000    -2.520000
# 79323W    WHITE CHERRY LIGHTS                    -8.000000   -54.000000
# 21144     PINK POODLE HANGING DECORATION        -12.000000    -4.560000
# D         Discount                              -15.506494   -73.976883
# 21645     ASSORTED TUTTI FRUTTI ROUND BOX       -24.000000   -39.600000
#
# [3916 rows x 2 columns]

# %%
# HISTOGRAMS

# %%
# DISTRIBUTION OF QUANTITY
plt.figure(figsize=(10, 6))
plt.hist(new_df2['Quantity'], bins=30, color='blue', alpha=0.7)
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()

# %%
# DISTRIBUTION OF UNIT PRICE
plt.figure(figsize=(10, 6))
plt.hist(new_df2['UnitPrice'], bins=30, color='green', alpha=0.7)
plt.title('Distribution of Unit Price')
plt.xlabel('Unit Price')
plt.ylabel('Frequency')
plt.show()

# %%
# DISTRIBUTION OF CUSTOMER IDs
plt.figure(figsize=(10, 6))
plt.hist(new_df2['CustomerID'], bins=30, color='red', alpha=0.7)
plt.title('Distribution of Customer IDs')
plt.xlabel('CustomerID')
plt.ylabel('Frequency')
plt.show()

# %%
# SCATTER PLOTS

# %%
# QUANTITY VS UNIT PRICE
plt.figure(figsize=(10, 6))
plt.scatter(df['Quantity'], df['UnitPrice'], alpha=0.5)
plt.title('Quantity vs Unit Price')
plt.xlabel('Quantity')
plt.ylabel('Unit Price')
plt.show()

# %%
# CUSTOMER SPENDING VS NUMBER OF ORDERS 
customer_spending = new_df2.groupby('CustomerID')['TotalAmount'].sum()
customer_orders = new_df2.groupby('CustomerID')['InvoiceNo'].nunique()

plt.figure(figsize=(10, 6))
plt.scatter(customer_orders, customer_spending)
plt.title('Customer Spending vs Number of Orders')
plt.xlabel('Number of Orders')
plt.ylabel('Total Spending')
plt.show()

# %% [markdown]
# # HEATMAPS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_excel("E:\online retail.xlsx")
numeric_data = df[['Quantity', 'UnitPrice', 'CustomerID']]
correlation_matrix = numeric_data.corr()
plt.figure(figsize=(7, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
import pandas as pd
df =pd.read_excel("E:\online retail.xlsx")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
